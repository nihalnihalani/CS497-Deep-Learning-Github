# %% [markdown]
# CPython   =>C
#
# Jython    => Java
#
# IronPython  => C#
#
# PyPy  => Subset of Python; Runs faster because of just-in-time-compiler

# %%
print("Hello World!")
print(4+5)

x = 6  #integer
myName="Gheni Abla"  #String
y = 8.90 #float

z = x * y
print(z)
print("%d * %f = %f"%(x,y,z))

x = x * 5
print(x)
myName = myName * 5
print(myName)

print(myName.lower())
print(myName.capitalize().upper())
# Out:
# Hello World!
# 9
# 53.400000000000006
# 6 * 8.900000 = 53.400000
# Gheni AblaGheni AblaGheni AblaGheni AblaGheni Abla
# gheni ablagheni ablagheni ablagheni ablagheni abla
# GHENI ABLAGHENI ABLAGHENI ABLAGHENI ABLAGHENI ABLA

# %%
#imports: modules
"Python Standard Library." 
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Python PEPs => Python enhancement proposals.
#
# PEP8 => They are style guides.

# %%
#Python variables
#dynamic, strongly typed
#suggestion: name your variable with meaningful names

x = 123 			# integer
print(x)
x = 3.14 			# double float
print(x)
x = 0xA0F           #Hexa-decimal
print(x)
x =  0o37             #Octal
print(x)
x = 0b101 
print(x)
x = "hello" 	    # string
print(x)
x = [0,1,2] 		# list
x = (0,1,2) 		# tuple
#x = open("hello.py", "r) 	# file

#You can also assign a single value to several variables simultaneously multiple 
#assignments.

#Variable a,b and c are assigned to the same memory location,with the value of 1
a = b = c = 1	
xyz:int = 21

type(xyz)    

zzz=int(123)
print(zzz)
zzz=float(123)
print(zzz)
# Out:
# 123
# 3.14
# 2575
# 31
# 5
# hello
# 123
# 123.0

# %%
#math operations
print(2+3) 
print(2*3)
print(2**3)
print(2/3)
print(2%3)

#math functions
import math
x=-123.123
print(abs(x))
print(math.ceil(x))
print(math.floor(x))
math.pow(3, 2)
math.sqrt(123)
# Out:
# 5
# 6
# 8
# 0.6666666666666666
# 2
# 123.123
# -123
# -124
# 11.090536506409418

# %%
#commonly used modules, packages: sys, re, os
import sys
print(sys.version)

import scipy
print('scipy: %s' % scipy.__version__)
import numpy
print('numpy: %s' % numpy.__version__)

import matplotlib
print('matplotlib: %s' % matplotlib.__version__)

import pandas
print('pandas: %s' % pandas.__version__)

import statsmodels
print('statsmodels: %s' % statsmodels.__version__)

import sklearn
print('sklearn: %s' % sklearn.__version__)

#deep learning packages
import tensorflow
print('tensorflow: %s' % tensorflow.__version__)

# keras
import keras
print('keras: %s' % keras.__version__)

#pytorch
import torch
print('pytorch: %s' % torch.__version__)
# Out:
# 3.6.8 (default, Jan 14 2019, 11:02:34)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]
# scipy: 1.3.1
# numpy: 1.16.4
# matplotlib: 3.0.3
# pandas: 0.24.2
# statsmodels: 0.10.1
# sklearn: 0.21.3
# tensorflow: 1.14.0
# keras: 2.2.5
# Using TensorFlow backend.
# pytorch: 1.1.0

# %%
import math as m
print(m.ceil(2.3))
# Out:
# 3

# %%
#user defined functions
def print_hello():
    print("hello")
    
def print_message(message):
    print(message)

def repeat_once(info):
    return info + " " + info

print_hello()    
print_message("Abla")

repeat_once("Hello")
# Out:
# hello
# Abla
# 'Hello Hello'

# %%
#help()  and dir() for getting help
#help(): documentation strings for various modules, functions, and methods. 
help(len)
#help(sys)
#help("abc".split())

#dir()
#dir(torch)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
#
# Help on list object:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...
