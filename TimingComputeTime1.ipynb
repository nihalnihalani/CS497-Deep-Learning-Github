# %%
import time

#0,1,1,2,3,5,8,13,21...
def fib1(n):
    result = 0
    if n <= 2 and n >0:
        result = 1
    else:
        result = fib1(n-1) + fib1(n-2) 
        
    return result

def fib2(n):
    dict = {}
    return fibonacci2(n, dict)

def fibonacci2(n, dict):
    result = 0
    if n <= 2 and n >0:
        result = 1
    else:
        if n in dict:
            result = dict[n]
        else:
            dict[n] = fibonacci2(n-1, dict) + fibonacci2(n-2, dict)
            result = dict[n]
    return result

n =30
t0 = time.process_time()
f1 = fib1(n)
t1 = time.process_time()
print(f1)
t2= time.process_time()
f2 = fib2(n)
t3 = time.process_time()
print("f1=", f1, "computation time=" +str(1000*(t1 - t0)) )
print("f2=", f2, "computation time=" +str(1000*(t2 - t1)) )
# Out:
# 832040
# f1= 832040 computation time=201.33404399999222
# f2= 832040 computation time=0.3855759999851216
